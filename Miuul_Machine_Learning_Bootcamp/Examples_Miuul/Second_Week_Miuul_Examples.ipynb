# %% [markdown]
# #  İkinci Hafta Uygulamaları

# %% [markdown]
# ###### Görev 1: Seaborn kütüphanesi içerisinden Titanic veri setini tanımlayınız.

# %%
import seaborn as sns
import pandas as pd

# %%
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ###### Görev 2: Titanic veri setindeki kadın ve erkek yolcuların sayısını bulunuz.

# %%
df["who"].value_counts()["man"]
# Out:
# 537

# %%
df["who"].value_counts()["woman"]
# Out:
# 271

# %% [markdown]
# ###### Görev 3: Her bir sutuna ait unique değerlerin sayısını bulunuz.

# %%
for col in df.columns:
    print(f"{df[col].name} unique deger sayisi : {len(df[col].unique())}")
# Out:
# survived unique deger sayisi : 2
# pclass unique deger sayisi : 3
# sex unique deger sayisi : 2
# age unique deger sayisi : 89
# sibsp unique deger sayisi : 7
# parch unique deger sayisi : 7
# fare unique deger sayisi : 248
# embarked unique deger sayisi : 4
# class unique deger sayisi : 3
# who unique deger sayisi : 3
# adult_male unique deger sayisi : 2
# deck unique deger sayisi : 8
# embark_town unique deger sayisi : 4
# alive unique deger sayisi : 2
# alone unique deger sayisi : 2

# %% [markdown]
# ###### Görev 4: pclass değişkeninin unique değerlerinin sayısını bulunuz

# %%
len(df["pclass"].unique())
# Out:
# 3

# %% [markdown]
# ###### Görev 5: pclass ve parch değişkenlerinin unique değerlerinin sayısını bulunuz

# %%
for col in ["pclass","parch"]:
    print(f"{col} unique deger sayisi :{len(df[col].unique())}")
# Out:
# pclass unique deger sayisi :3
# parch unique deger sayisi :7

# %% [markdown]
# ###### Görev 6: embarked değişkeninin tipini kontrol ediniz. Tipini category olarak değiştiriniz ve tekrar kontrol ediniz.

# %%
df["embarked"].dtype
# Out:
# dtype('O')

# %%
df["embarked"] = df["embarked"].astype("category")

# %%
df["embarked"].dtype
# Out:
# CategoricalDtype(categories=['C', 'Q', 'S'], ordered=False)

# %% [markdown]
# ###### Görev 7: embarked değeri C olanların tüm bilgelerini gösteriniz

# %%
df.loc[df["embarked"] == "C"]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 19          1       3  female   NaN      0      0   7.2250        C   Third
# 26          0       3    male   NaN      0      0   7.2250        C   Third
# 30          0       1    male  40.0      0      0  27.7208        C   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 866         1       2  female  27.0      1      0  13.8583        C  Second
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck embark_town alive  alone
# ...

# %% [markdown]
# ###### Görev 8: embarked değeri S olmayanların tüm bilgelerini gösteriniz.

# %%
df.loc[df["embarked"] != "S"]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 16          0       3    male   2.0      4      1  29.1250        Q   Third
# 19          1       3  female   NaN      0      0   7.2250        C   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck embark_town alive  alone
# ...

# %% [markdown]
# ###### Görev 9: Yaşı 30 dan küçük ve kadın olan yolcuların tüm bilgilerini gösteriniz.

# %%
df.loc[(df["age"] < 30) & (df["who"] == "woman")]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 38          0       3  female  18.0      2      0  18.0000        S   Third
# 41          0       2  female  27.0      1      0  21.0000        S  Second
# 44          1       3  female  19.0      0      0   7.8792        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 866         1       2  female  27.0      1      0  13.8583        C  Second
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ###### Görev 10: Fare'i 500'den büyük veya yaşı 70 den büyük yolcuların bilgilerini gösteriniz.

# %%
df.loc[(df["fare"] > 500) | (df["age"] > 70)]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 96          0       1    male  71.0      0      0   34.6542        C  First
# 116         0       3    male  70.5      0      0    7.7500        Q  Third
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 493         0       1    male  71.0      0      0   49.5042        C  First
# 630         1       1    male  80.0      0      0   30.0000        S  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
# 851         0       3    male  74.0      0      0    7.7750        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# 96     man        True    A    Cherbourg    no   True
# 116    man        True  NaN   Queenstown    no   True
# 258  woman       False  NaN    Cherbourg   yes   True
# 493    man        True  NaN    Cherbourg    no   True
# ...

# %% [markdown]
# ###### Görev 10: Fare'i 500'den büyük veya yaşı 70 den büyük yolcuların bilgilerini gösteriniz.

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# ###### Görev 12: who değişkenini dataframe’den çıkarınız.

# %%
df.drop("who",axis=1)
#Eğer kalıcı hale getirmek istersek aşagıdaki kodu kullanabiriz
#df.drop("who",axis=1,inplace=True)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ###### Görev 13: deck değikenindeki boş değerleri deck değişkenin en çok tekrar eden değeri (mode) ile doldurunuz.

# %%
df["deck"].isnull()
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: deck, Length: 891, dtype: bool

# %%
df["deck"] = df["deck"].fillna(value=df.deck.mode()[0])
#Değişkene atamadan inplace argumanını True yaparak da kaydetmis oluruz
#df["deck"].fillna(value=df.deck.mode()[0],inplace = True)

# %%
df.deck.isnull().sum()
# Out:
# 0

# %% [markdown]
# ###### Görev 14: age değikenindeki boş değerleri age değişkenin medyanı ile doldurunuz

# %%
df["age"].fillna(value=df["age"].median(),inplace=True)

# %%
df.age.isnull().sum()
# Out:
# 0

# %% [markdown]
# ###### Görev 15: survived değişkeninin pclass ve cinsiyet değişkenleri kırılımınında sum, count, mean değerlerini bulunuz.

# %%
df.groupby(["pclass","sex"]).agg({"survived":["sum","count","mean"]})
# Out:
#               survived
#                    sum count      mean
# pclass sex
# 1      female       91    94  0.968085
#        male         45   122  0.368852
# 2      female       70    76  0.921053
#        male         17   108  0.157407
# 3      female       72   144  0.500000
#        male         47   347  0.135447

# %% [markdown]
# ##### Görev 16: 30 yaşın altında olanlar 1, 30'a eşit ve üstünde olanlara 0 vericek bir fonksiyon yazın. Yazdığınız fonksiyonu kullanarak titanik veri setinde age_flag adında bir değişken oluşturunuz oluşturunuz. (apply ve lambda yapılarını kullanınız)

# %%
df["age_flag"] = df["age"].apply(lambda x: 1 if x>30 else 0)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  age_flag
# 0    man        True    C  Southampton    no  False         0
# 1  woman       False    C    Cherbourg   yes  False         1
# 2  woman       False    C  Southampton   yes   True         0
# 3  woman       False    C  Southampton   yes  False         1
# 4    man        True    C  Southampton    no   True         1

# %% [markdown]
# ###### Görev 17: Seaborn kütüphanesi içerisinden Tips veri setini tanımlayınız.

# %%
df2 = sns.load_dataset("tips")
df2.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ###### Görev 18: Time değişkeninin kategorilerine (Dinner, Lunch) göre total_bill değerlerinin toplamını, min, max ve ortalamasını bulunuz.

# %%
df2.groupby("time").agg({"total_bill":["min","max","mean"]})
# Out:
#        total_bill
#               min    max       mean
# time
# Lunch        7.51  43.11  17.168676
# Dinner       3.07  50.81  20.797159

# %% [markdown]
# ###### Görev 19: Günlere ve time göre total_bill değerlerinin toplamını, min, max ve ortalamasını bulunuz.

# %%
df2.groupby(["day","time"]).agg({"total_bill":["min","max","mean"]})
# Out:
#             total_bill
#                    min    max       mean
# day  time
# Thur Lunch        7.51  43.11  17.664754
#      Dinner      18.78  18.78  18.780000
# Fri  Lunch        8.58  16.27  12.845714
#      Dinner       5.75  40.17  19.663333
# Sat  Lunch         NaN    NaN        NaN
#      Dinner       3.07  50.81  20.441379
# Sun  Lunch         NaN    NaN        NaN
#      Dinner       7.25  48.17  21.410000

# %% [markdown]
# ###### Görev 20: Lunch zamanına ve kadın müşterilere ait total_bill ve tip değerlerinin day'e göre toplamını, min, max ve ortalamasını bulunuz.

# %%
df_lunch_female = df2.loc[(df2["time"] == "Lunch") & (df2["sex"] == "Female")]
df_lunch_female
# Out:
#      total_bill   tip     sex smoker   day   time  size
# 82        10.07  1.83  Female     No  Thur  Lunch     1
# 85        34.83  5.17  Female     No  Thur  Lunch     4
# 117       10.65  1.50  Female     No  Thur  Lunch     2
# 118       12.43  1.80  Female     No  Thur  Lunch     2
# 119       24.08  2.92  Female     No  Thur  Lunch     4
# 121       13.42  1.68  Female     No  Thur  Lunch     2
# 124       12.48  2.52  Female     No  Thur  Lunch     2
# 125       29.80  4.20  Female     No  Thur  Lunch     6
# 127       14.52  2.00  Female     No  Thur  Lunch     2
# 128       11.38  2.00  Female     No  Thur  Lunch     2
# 131       20.27  2.83  Female     No  Thur  Lunch     2
# 132       11.17  1.50  Female     No  Thur  Lunch     2
# 133       12.26  2.00  Female     No  Thur  Lunch     2
# 134       18.26  3.25  Female     No  Thur  Lunch     2
# 135        8.51  1.25  Female     No  Thur  Lunch     2
# 136       10.33  2.00  Female     No  Thur  Lunch     2
# ...

# %%
df_lunch_female.groupby("day").agg({"total_bill" : ["sum","min","max","mean","count"],
                                    "tip" : ["sum","min","max","mean","count"]})
# Out:
#      total_bill                                  tip
#             sum    min    max      mean count    sum   min   max      mean count
# day
# Thur     516.11   8.35  43.11  16.64871    31  79.42  1.25  5.17  2.561935    31
# Fri       55.76  10.09  16.27  13.94000     4  10.98  2.00  3.48  2.745000     4
# Sat        0.00    NaN    NaN       NaN     0   0.00   NaN   NaN       NaN     0
# Sun        0.00    NaN    NaN       NaN     0   0.00   NaN   NaN       NaN     0

# %% [markdown]
# ###### Görev 21: size'i 3'ten küçük, total_bill'i 10'dan büyük olan siparişlerin ortalaması nedir? (loc kullanınız)

# %%
df2.loc[(df2["size"] < 3) & (df2["total_bill"] > 10)].mean()
# Out:
# C:\Users\Ali Can\AppData\Local\Temp\ipykernel_21564\1425225256.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df2.loc[(df2["size"] < 3) & (df2["total_bill"] > 10)].mean()
# total_bill    17.184965
# tip            2.638811
# size           1.993007
# dtype: float64

# %% [markdown]
# ###### Görev 22: total_bill_tip_sum adında yeni bir değişken oluşturunuz. Her bir müşterinin ödediği totalbill ve tip in toplamını versin

# %%
df2["total_bill_tip_sum"] = df2["total_bill"] + df2["tip"]
df2.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  total_bill_tip_sum
# 0       16.99  1.01  Female     No  Sun  Dinner     2               18.00
# 1       10.34  1.66    Male     No  Sun  Dinner     3               12.00
# 2       21.01  3.50    Male     No  Sun  Dinner     3               24.51
# 3       23.68  3.31    Male     No  Sun  Dinner     2               26.99
# 4       24.59  3.61  Female     No  Sun  Dinner     4               28.20

# %% [markdown]
# ##### Görev 23: total_bill_tip_sum değişkenine göre büyükten küçüğe sıralayınız ve ilk 30 kişiyi yeni bir dataframe'e atayınız.

# %%
df2 = df2.sort_values(by="total_bill_tip_sum")
df2 = df2.reset_index(drop=True)

# %%
df2.head()
# Out:
#    total_bill   tip     sex smoker   day    time  size  total_bill_tip_sum
# 0        3.07  1.00  Female    Yes   Sat  Dinner     1                4.07
# 1        5.75  1.00  Female    Yes   Fri  Dinner     2                6.75
# 2        7.25  1.00  Female     No   Sat  Dinner     1                8.25
# 3        7.56  1.44    Male     No  Thur   Lunch     2                9.00
# 4        7.74  1.44    Male    Yes   Sat  Dinner     2                9.18

# %%
df3 = df2[0:30]
df3
# Out:
#     total_bill   tip     sex smoker   day    time  size  total_bill_tip_sum
# 0         3.07  1.00  Female    Yes   Sat  Dinner     1                4.07
# 1         5.75  1.00  Female    Yes   Fri  Dinner     2                6.75
# 2         7.25  1.00  Female     No   Sat  Dinner     1                8.25
# 3         7.56  1.44    Male     No  Thur   Lunch     2                9.00
# 4         7.74  1.44    Male    Yes   Sat  Dinner     2                9.18
# 5         7.51  2.00    Male     No  Thur   Lunch     2                9.51
# 6         8.51  1.25  Female     No  Thur   Lunch     2                9.76
# 7         8.35  1.50  Female     No  Thur   Lunch     2                9.85
# 8         8.52  1.48    Male     No  Thur   Lunch     2               10.00
# 9         8.58  1.92    Male    Yes   Fri   Lunch     1               10.50
# 10        8.77  2.00    Male     No   Sun  Dinner     2               10.77
# ...
